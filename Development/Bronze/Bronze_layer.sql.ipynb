# %%
# %sql
-- Customer Dataset
CREATE TABLE IF NOT EXISTS wsdbrksecommerce.bronze.customer_dataset
USING DELTA
AS
SELECT *
FROM parquet.`abfss://rawparquat@saneccomercep2.dfs.core.windows.net/customers_dataset.parquet`;


-- Order Items Dataset
CREATE TABLE IF NOT EXISTS wsdbrksecommerce.bronze.order_items_dataset
USING DELTA
AS
SELECT *
FROM parquet.`abfss://rawparquat@saneccomercep2.dfs.core.windows.net/order_items_dataset.parquet`;


-- Orders Dataset
CREATE TABLE IF NOT EXISTS wsdbrksecommerce.bronze.orders_dataset
USING DELTA
AS
SELECT *
FROM parquet.`abfss://rawparquat@saneccomercep2.dfs.core.windows.net/orders_dataset.parquet`;


-- Product Category Translation
CREATE TABLE IF NOT EXISTS wsdbrksecommerce.bronze.product_category_name_translation
USING DELTA
AS
SELECT *
FROM parquet.`abfss://rawparquat@saneccomercep2.dfs.core.windows.net/product_category_name_translation.parquet`;


-- Products Dataset
CREATE TABLE IF NOT EXISTS wsdbrksecommerce.bronze.products_dataset
USING DELTA
AS
SELECT *
FROM parquet.`abfss://rawparquat@saneccomercep2.dfs.core.windows.net/products_dataset.parquet`;


-- Sellers Dataset
CREATE TABLE IF NOT EXISTS wsdbrksecommerce.bronze.sellers_dataset
USING DELTA
AS
SELECT *
FROM parquet.`abfss://rawparquat@saneccomercep2.dfs.core.windows.net/sellers_dataset.parquet`;
